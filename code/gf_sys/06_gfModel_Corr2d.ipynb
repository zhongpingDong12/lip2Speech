# %% [markdown]
# ### Import libraries

# %%
# Import libraries
import fnmatch
import scipy.io as sio
import os
from keras.models import Sequential, Model, load_model
from keras import backend as BK
import numpy as np
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Step.1: define variable and data path

# %%
speaker = 's16'
compareGf = 68

model ='s16'

# Step.1: define variable and data path
print('***** Step.1: Define variable and data path *******')
oriSpecPath = 'D:/Mrs_backup/speech_test/AudSpecs/'+speaker+'/'

# get the model input path 
modelInputPath = 'D:/Mrs_backup/speech_test/model_input/gf/'+speaker+'/'

#modelInputPath ='D:/Mrs_backup/speech_test/model_output/GF_100/'+speaker+'_gf/'
autoModelPath = 'D:/Mrs_backup/speech_test/autoencoder/'+speaker+'_trainModel/'

lipModelPath = 'D:/Mrs_backup/speech_test/model_output/gf/'+model+'/'

print('Original spectrogram path is: '+ str(oriSpecPath)+'\n') 
print('Model input path is: '+ str(modelInputPath)+'\n')
print('Autoencoder model path is: '+ str(autoModelPath)+'\n')
print('Main Model path is: '+ str(lipModelPath)+'\n')

evalPath = 'D:/Mrs_backup/speech_test/corr2d/gf/'+model+'/'
#evalPath = 'D:/Mrs_backup/speech_test/corr2d/unseen/gf/'+model+'_to_'+speaker+'/'
if not os.path.exists(evalPath):
    os.mkdir(evalPath )
    
# evalPath = evalPath + speaker+'/'
# if not os.path.exists(evalPath):
#     os.mkdir(evalPath )
print('Result output path is: '+ str(evalPath)+'\n')
print('---------------  End of Step.1  --------------------- ')
# Out:
# ***** Step.1: Define variable and data path *******
# Original spectrogram path is: D:/Mrs_backup/speech_test/AudSpecs/s16/
#
# Model input path is: D:/Mrs_backup/speech_test/model_input/gf/s16/
#
# Autoencoder model path is: D:/Mrs_backup/speech_test/autoencoder/s16_trainModel/
#
# Main Model path is: D:/Mrs_backup/speech_test/model_output/gf/s16/
#
# Result output path is: D:/Mrs_backup/speech_test/corr2d/gf/s16/
#
# ---------------  End of Step.1  ---------------------

# %% [markdown]
# ### Step.2: count train and test set

# %%
def countTrainAndTest(modelInputPath,numSlices):
    numTrain=len(fnmatch.filter(os.listdir(modelInputPath),'preprocessed_data_final_part*.mat'))
    mat=sio.loadmat(modelInputPath+'preprocessed_data_final_validation.mat')
    print(mat['video_input'].shape)
    numTest = int(mat['video_input'].shape[0]/numSlices)
    return numTrain,numTest


print('***** Step.2: Count train and test set *******')
numSlices=15
numTrain,numTest = countTrainAndTest(modelInputPath,numSlices)
print('Number of training set is: '+ str(numTrain))
print('Number of test set is: '+ str(numTest))
print('---------------  End of Step.2  --------------------- ')
# Out:
# ***** Step.2: Count train and test set *******
# (300, 26, 21)
# Number of training set is: 80
# Number of test set is: 20
# ---------------  End of Step.2  ---------------------

# %% [markdown]
# ### Step.3: load data and get input shape

# %%
def getOriAudioSize(oriSpecPath):
    filePath = oriSpecPath + os.listdir(oriSpecPath)[0]
    mat=sio.loadmat(filePath)
    audioSize = mat['y'].shape
    return audioSize

# Step.3: load data and get input shape
print('***** Step.3: Count train and test set *******')
audioSize = getOriAudioSize(oriSpecPath)
audioSpecLength = audioSize[0]
audioSpecFreq = audioSize[1]
print('Audio Spectrogram length is: '+ str(audioSpecLength))
print('Audio Spectrogram Freqence is: '+ str(audioSpecFreq))
print('---------------  End of Step.3  --------------------- ')
# Out:
# ***** Step.3: Count train and test set *******
# Audio Spectrogram length is: 376
# Audio Spectrogram Freqence is: 128
# ---------------  End of Step.3  ---------------------

# %% [markdown]
# ### Step.4: load autoencoder and main model

# %%
# Define cost function
def corr2_mse_loss(a,b):
    a = BK.tf.subtract(a, BK.tf.reduce_mean(a))
    b = BK.tf.subtract(b, BK.tf.reduce_mean(b))
    tmp1 = BK.tf.reduce_sum(BK.tf.multiply(a,a))
    tmp2 = BK.tf.reduce_sum(BK.tf.multiply(b,b))
    tmp3 = BK.tf.sqrt(BK.tf.multiply(tmp1,tmp2))
    tmp4 = BK.tf.reduce_sum(BK.tf.multiply(a,b))
    r = -BK.tf.divide(tmp4,tmp3)
    m=BK.tf.reduce_mean(BK.tf.square(BK.tf.subtract(a, b)))
    rm=BK.tf.add(r,m)
    return rm

def loadModel(autoModelPath,lipModelPath):
    # Loading AutoEncoder model
    autoModel=load_model(autoModelPath+'autoencoder.h5',custom_objects={'corr2_mse_loss': corr2_mse_loss})
    autoModel.load_weights(autoModelPath+'autoencoder_weights.h5')
    
    #  Loading LipReading model
    lipModel=load_model(lipModelPath+'model_LipReading.h5',custom_objects={'corr2_mse_loss': corr2_mse_loss})
    #Best weights
    lipModel.load_weights(lipModelPath+'Best_weights_LipReading.h5')
    return autoModel,lipModel


print('***** Step.5: Load autoencoder and main model *******')
autoModel,lipModel = loadModel(autoModelPath,lipModelPath)
print('Autoencoder and lipReading model has loaded.... ')
print('---------------  End of Step.5  --------------------- ')
# Out:
# ***** Step.5: Load autoencoder and main model *******
# Autoencoder and lipReading model has loaded....
# ---------------  End of Step.5  ---------------------

# %% [markdown]
# ### Step.5: load original spectrogram, generate autoencoder spectrogram and predicted spectrogram

# %%
def corr2(a,b):
    k = np.shape(a)
    H=k[0]
    W=k[1]
    c = np.zeros((H,W))
    d = np.zeros((H,W))
    e = np.zeros((H,W))

    #Calculating mean values
    AM=np.mean(a)
    BM=np.mean(b)  

    #Calculating terms of the formula
    for ii in range(H):
        for jj in range(W):
            c[ii,jj]=(a[ii,jj]-AM)*(b[ii,jj]-BM)
            d[ii,jj]=(a[ii,jj]-AM)**2
            e[ii,jj]=(b[ii,jj]-BM)**2

    #Formula itself
    r = np.sum(c)/float(np.sqrt(np.sum(d)*np.sum(e)))
    return r

#Define get_activations function
def get_activations(model, layer_in, layer_out, X_batch):
    get_activations = BK.function([model.layers[layer_in].input, BK.learning_phase()], [model.layers[layer_out].output])
    activations = get_activations([X_batch,0])
    return activations

def getPredictedAudio(modelOutput,bottleFeature,sliceLength):
    specOutput=np.reshape(modelOutput,(modelOutput.shape[0],bottleFeature,sliceLength))
    specOutput2=np.concatenate(specOutput,axis=1)
    decodeOutput =get_activations(autoModel, 13, 19, specOutput2.T)[0]
    finalPredictSpec = np.power(decodeOutput,3)
    return finalPredictSpec


def getAutoSpec(oriSpec):
    oriOutput = autoModel.predict(np.power(oriSpec,.3))
    autoSpec = np.power(oriOutput,3)
    return autoSpec

def getAutoSpec2(oriSpec):
    oriOutput = autoModel.predict(np.power(oriSpec,.3))
    autoSpec = np.power(oriOutput,3)
    return autoSpec

def predictSpec(inputFile):
    trainInput = sio.loadmat(inputFile)['video_input']
    modelOutput = lipModel.predict(trainInput) 
    finalPredictSpec = getPredictedAudio(modelOutput,bottleFeature=32,sliceLength=26)
    return finalPredictSpec

def predictSpecTest(testInput):
    modelOutput = lipModel.predict(testInput) 
    finalPredictSpec = getPredictedAudio(modelOutput,bottleFeature=32,sliceLength=26)
    print(finalPredictSpec.shape)
    return finalPredictSpec

# %%
trainAutoCorr = np.empty((numTrain), np.dtype('float32'))
trainPreCorr = np.empty((numTrain), np.dtype('float32'))
testAutoCorr = np.empty((numTest), np.dtype('float32'))
testPreCorr = np.empty((numTest), np.dtype('float32'))

print('---------- Load train file -----------------')
trainFile = fnmatch.filter(os.listdir(modelInputPath),'preprocessed_data_final_part*.mat')
trainResult = evalPath+'train/'
if not os.path.exists(trainResult):
    os.mkdir(trainResult )
cor2DTrainPath = evalPath + 'cor2D_train.mat'

print('---------- Load test file -----------------')
testData = sio.loadmat(modelInputPath+'preprocessed_data_final_validation.mat')['video_input']  
testResult = evalPath+'test/'
if not os.path.exists(testResult):
    os.mkdir(testResult)  
cor2DTestPath = evalPath + 'cor2D_test.mat'
# Out:
# ---------- Load train file -----------------
# ---------- Load test file -----------------

# %%
print('***** Step.5: load original spectrogram and Generate autoencoder spectrogram *******')  
i=0  
testCount = 0
for count, filename in enumerate(sorted(os.listdir(oriSpecPath)),start=0): 

    # Get the train result
    if count in range(numTrain):
        audioFile  =oriSpecPath+ filename 
        print('Audio File is:' +audioFile)

        # Get original spectrogram
        oriSpec =sio.loadmat(audioFile)['y']
        #print('Original spectrogram shape is:'+ str(oriSpec.shape))
        
        #Get autoencoder spectrogram
#         autoSpec = getAutoSpec(oriSpec)
#         autoCorr = corr2(oriSpec,autoSpec)
#         trainAutoCorr[count] = autoCorr
#         print('Autoencoder spectrogram shape is:'+ str(autoSpec.shape))
#         print('Reconstruted spectrogram from autoencoder with correlation '+str(autoCorr))  

        #Get the predicted spectrogram and save it into train set
        inputFile= modelInputPath+trainFile[count]
        finalPredictSpec = predictSpec(inputFile)
        sio.savemat(trainResult+filename, mdict={'audio_input':finalPredictSpec})
    
        preCorr = corr2(oriSpec,finalPredictSpec)
        trainPreCorr[count] = preCorr
        
        #print('Final predicted spectrogram shape is:'+ str(finalPredictSpec.shape))
        print('Reconstruted spectrogram from lipreading model with correlation '+str(preCorr)+'\n')
        
    else:
        audioFile  =oriSpecPath+ filename 
        print('Audio File is:' +audioFile) 
        
        # Get original spectrogram
        oriSpec =sio.loadmat(audioFile)['y']
        
#         # Get autoencoder spectrogram
#         autoSpec = getAutoSpec(oriSpec)
#         autoCorr = corr2(oriSpec,autoSpec)
#         testAutoCorr[testCount] = autoCorr
        
        # Get the predicted spectrogram and save it into test set
        testInput = testData[i:(i+numSlices),]
        #print(testInput.shape)
        finalPredictSpec = predictSpecTest(testInput)
        sio.savemat(testResult+filename, mdict={'audio_input':finalPredictSpec})
        
        preCorr = corr2(oriSpec,finalPredictSpec)
        testPreCorr[testCount] = preCorr
        
        #print('Final predicted spectrogram shape is:'+ str(finalPredictSpec.shape))
        print('Reconstruted spectrogram from lipreading model with correlation '+str(preCorr)+'\n')
        i=i+numSlices
        testCount=testCount+1
        
sio.savemat(cor2DTrainPath, mdict={'corr2':trainPreCorr})
sio.savemat(cor2DTestPath, mdict={'corr2':testPreCorr})
print('Correclation value from training set has been saved in path: '+ str(cor2DTrainPath))
print('Correclation value from test set has been saved in path: '+ str(cor2DTestPath))
print('Average correlation value from training set is: '+str(np.mean(trainPreCorr)))
print('Average correlation value from test set is: '+str(np.mean(testPreCorr))+'\n')
# Out:
# ***** Step.5: load original spectrogram and Generate autoencoder spectrogram *******
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/000.mat
# Reconstruted spectrogram from lipreading model with correlation 0.670082952636542
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/001.mat
# Reconstruted spectrogram from lipreading model with correlation 0.79997671795368
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/002.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8130479836603407
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/003.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7955097166358595
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/004.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7447616062002899
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/005.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6883877052477609
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/006.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7193599914066927
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/007.mat
# Reconstruted spectrogram from lipreading model with correlation 0.780561778115104
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/008.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8187256363746995
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/009.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8316130352801604
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/010.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7760292423382548
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/011.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8006986314301845
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/012.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7280097527922217
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/013.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8441245547831239
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/014.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7161629559620544
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/015.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7264893859630154
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/016.mat
# Reconstruted spectrogram from lipreading model with correlation 0.785357826329013
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/017.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8110784459615845
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/018.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7822120003677634
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/019.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8281419344453949
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/020.mat
# Reconstruted spectrogram from lipreading model with correlation 0.5457175992569009
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/021.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7050429580400239
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/022.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8259368674298725
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/023.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6920779723718653
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/024.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7821047704160077
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/025.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7051322640315857
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/026.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6745708318064912
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/027.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6440693169953959
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/028.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7455059759763177
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/029.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7502568403741375
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/030.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8209038465666654
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/031.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8132342017750486
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/032.mat
# Reconstruted spectrogram from lipreading model with correlation 0.36325427589871623
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/033.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7439509660921145
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/034.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8473277156705562
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/035.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6129889954329089
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/036.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6963919323588594
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/037.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8066020026818149
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/038.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7208369809244518
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/039.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8175099645079567
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/040.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8374319582954695
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/041.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8201900016669267
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/042.mat
# Reconstruted spectrogram from lipreading model with correlation 0.786693458401867
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/043.mat
# Reconstruted spectrogram from lipreading model with correlation 0.5842996768186268
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/044.mat
# Reconstruted spectrogram from lipreading model with correlation 0.797600283122983
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/045.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7480896354247732
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/046.mat
# Reconstruted spectrogram from lipreading model with correlation 0.679955267822775
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/047.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6246707319246491
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/048.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8093586082771971
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/049.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7147037716393633
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/050.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8595410655244902
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/051.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8328884467370695
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/052.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8563218468628859
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/053.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8028186785301252
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/054.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8611751397068701
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/055.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8291491864617553
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/056.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8221909375931971
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/057.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7415445501996359
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/058.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7193672580922048
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/059.mat
# Reconstruted spectrogram from lipreading model with correlation 0.6830164351164929
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/060.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8449249270489093
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/061.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8365351623743895
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/062.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7996738026192844
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/063.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7779288967020375
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/064.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7647269062836816
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/065.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8634501235025485
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/066.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7982184209013261
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/067.mat
# Reconstruted spectrogram from lipreading model with correlation 0.800238205631477
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/068.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8799426108513327
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/069.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8646303625963083
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/070.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8458181710286036
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/071.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8092705364699802
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/072.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8609845938978247
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/073.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7968958731665444
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/074.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8008143772411962
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/075.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8498720690880748
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/076.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8398642789607401
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/077.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8590397171775604
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/078.mat
# Reconstruted spectrogram from lipreading model with correlation 0.7693216063396642
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/079.mat
# Reconstruted spectrogram from lipreading model with correlation 0.8325301641723798
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/080.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.46588836952313456
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/081.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.36007411653935045
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/082.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.4389625161376348
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/083.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.4783086219131815
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/084.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.20229423423435067
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/085.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.6028739224367563
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/086.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.483728458548497
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/087.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.48931418196658677
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/088.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3017722973320009
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/089.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.4317491881873304
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/090.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.25057288927130666
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/091.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.5477866064504253
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/092.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.07579910524673054
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/093.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.5127599222833623
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/094.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.31236751114777256
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/095.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3986205784949051
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/096.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.6353162457404106
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/097.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.40386827410526704
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/098.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.5469441602001655
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s16/099.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.5290063012089781
#
# Correclation value from training set has been saved in path: D:/Mrs_backup/speech_test/corr2d/gf/s16/cor2D_train.mat
# Correclation value from test set has been saved in path: D:/Mrs_backup/speech_test/corr2d/gf/s16/cor2D_test.mat
# Average correlation value from training set is: 0.77099293
# Average correlation value from test set is: 0.42340034

# %% [markdown]
# ### Step 6:  Result analysis

# %%
def removeOutliers(corrData):
    # calculate summary statistics
    data_mean, data_std = mean(corrData), std(corrData)
    #print('Original data mean is '+ str(data_mean))

    # identify outliers
    cut_off = data_std * 2
    lower, upper = data_mean - cut_off, data_mean + cut_off
    
    # identify outliers
    outliers = [x for x in corrData if x < lower or x > upper]
    #print('Identified outliers: %d' % len(outliers)+ ', which is '+str(outliers))

    # remove outliers
    outliers_removed = [x for x in corrData if x >= lower and x <= upper]
    #print('Non-outlier observations: %d' % len(outliers_removed))
    print(outliers_removed)
    
    avgCorr = np.mean(outliers_removed)
    
    return avgCorr

# %%
maxCorr = evalPath+'maxCorr/'
if not os.path.exists(maxCorr):
    os.mkdir(maxCorr )

# %% [markdown]
# ### Training set result analysis

# %%
print(trainPreCorr)
stdAvgTrain = np.mean(trainPreCorr)
print('Average correlation value from training set is: '+str(stdAvgTrain))
stdAvgTrain = removeOutliers(trainPreCorr)
#stdAvgTrain = np.mean(trainPreCorr)
print('Average correlation value from training set is: '+str(stdAvgTrain))
# Out:
# [0.6700829  0.7999767  0.813048   0.7955097  0.7447616  0.6883877
#  0.71936    0.7805618  0.81872565 0.83161306 0.7760292  0.80069864
#  0.72800976 0.84412456 0.716163   0.72648937 0.78535783 0.8110784
#  0.782212   0.8281419  0.5457176  0.70504296 0.82593685 0.692078
#  0.7821048  0.70513225 0.67457086 0.6440693  0.745506   0.75025684
#  0.82090384 0.8132342  0.36325428 0.74395096 0.8473277  0.612989
#  0.69639194 0.806602   0.720837   0.81750995 0.83743197 0.82019
#  0.78669345 0.5842997  0.79760027 0.7480896  0.67995524 0.62467074
#  0.8093586  0.7147038  0.85954106 0.8328884  0.8563219  0.80281866
#  0.8611751  0.8291492  0.82219094 0.74154454 0.71936727 0.6830164
#  0.8449249  0.83653516 0.7996738  0.7779289  0.7647269  0.8634501
#  0.7982184  0.8002382  0.8799426  0.86463034 0.84581816 0.80927056
#  0.8609846  0.79689586 0.8008144  0.84987205 0.83986425 0.8590397
#  0.7693216  0.83253014]
# Average correlation value from training set is: 0.77099293
# [0.6700829, 0.7999767, 0.813048, 0.7955097, 0.7447616, 0.6883877, 0.71936, 0.7805618, 0.81872565, 0.83161306, 0.7760292, 0.80069864, 0.72800976, 0.84412456, 0.716163, 0.72648937, 0.78535783, 0.8110784, 0.782212, 0.8281419, 0.70504296, 0.82593685, 0.692078, 0.7821048, 0.70513225, 0.67457086, 0.6440693, 0.745506, 0.75025684, 0.82090384, 0.8132342, 0.74395096, 0.8473277, 0.612989, 0.69639194, 0.806602, 0.720837, 0.81750995, 0.83743197, 0.82019, 0.78669345, 0.79760027, 0.7480896, 0.67995524, 0.62467074, 0.8093586, 0.7147038, 0.85954106, 0.8328884, 0.8563219, 0.80281866, 0.8611751, 0.8291492, 0.82219094, 0.74154454, 0.71936727, 0.6830164, 0.8449249, 0.83653516, 0.7996738, 0.7779289, 0.7647269, 0.8634501, 0.7982184, 0.8002382, 0.8799426, 0.86463034, 0.84581816, 0.80927056, 0.8609846, 0.79689586, 0.8008144, 0.84987205, 0.83986425, 0.8590397, 0.7693216, 0.83253014]
# Average correlation value from training set is: 0.7816385

# %%
(maxCorrtTrain,maxIndexTrain) = max((v,i) for i,v in enumerate(trainPreCorr))
print ('Maxmum correlation value from training set is: '+str(maxCorrtTrain)+' on video: '+str(maxIndexTrain))
# Out:
# Maxmum correlation value from training set is: 0.8799426 on video: 68

# %%
maxCorrTrain = maxCorr+'train/'
if not os.path.exists(maxCorrTrain):
    os.mkdir(maxCorrTrain )

# %%
# Plot maxmum spectrogram from train set and save the output

# Load maxOri spectrogram
maxNum="{number:03}".format(number=(maxIndexTrain))

maxOriPath = oriSpecPath+ maxNum+'.mat'
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTrain+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = trainResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTrain+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/gf/s16/train/068.mat
# (390, 128)

# %%
# Plot maxmum spectrogram from train set and save the output
# Load maxOri spectrogram
#maxNum="{number:03}".format(number=(maxIndexTrain))
maxNum="{number:03}".format(number=(compareGf))

maxOriPath = oriSpecPath+ maxNum+'.mat'
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTrain+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = trainResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTrain+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/gf/s16/train/068.mat
# (390, 128)

# %% [markdown]
# ### Test set result analysis

# %%
print(testPreCorr)
print('Average correlation value from training set is: '+str(np.mean(testPreCorr)))
stdAvgTest = removeOutliers(testPreCorr)
print('Average correlation value from training set is: '+str(stdAvgTest))
# Out:
# [0.46588838 0.3600741  0.43896252 0.47830862 0.20229423 0.6028739
#  0.48372847 0.48931417 0.3017723  0.4317492  0.2505729  0.5477866
#  0.07579911 0.5127599  0.3123675  0.39862058 0.63531625 0.4038683
#  0.54694414 0.5290063 ]
# Average correlation value from training set is: 0.42340034
# [0.46588838, 0.3600741, 0.43896252, 0.47830862, 0.20229423, 0.6028739, 0.48372847, 0.48931417, 0.3017723, 0.4317492, 0.2505729, 0.5477866, 0.5127599, 0.3123675, 0.39862058, 0.63531625, 0.4038683, 0.54694414, 0.5290063]
# Average correlation value from training set is: 0.44169515

# %%
(maxCorrtTest,maxIndexTest) = max((v,i) for i,v in enumerate(testPreCorr))
print ('Maxmum correlation value from test set is: '+str(maxCorrtTest)+' on video: '+str(maxIndexTest))
# Out:
# Maxmum correlation value from test set is: 0.63531625 on video: 16

# %%
maxCorrTest = maxCorr+'test/'
if not os.path.exists(maxCorrTest):
    os.mkdir(maxCorrTest )

# %%
# Load maxOri spectrogram
maxNum="{number:03}".format(number=(maxIndexTest+numTrain))
maxOriPath = oriSpecPath+ maxNum+'.mat'
print(maxOriPath)
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTest+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTest+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = testResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTest+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTest+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# D:/Mrs_backup/speech_test/AudSpecs/s16/096.mat
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/gf/s16/test/096.mat
# (390, 128)

# %% [markdown]
# ### Save avg and max value from training and test set

# %%
sio.savemat(evalPath+'/corr2D.mat', mdict={'train_avg':stdAvgTrain,
                                           'train_max':maxCorrtTrain,
                                           'train_index':maxIndexTrain,
                                           'test_avg':stdAvgTest, 
                                           'test_max':maxCorrtTest,
                                           'test_index':maxIndexTest})
