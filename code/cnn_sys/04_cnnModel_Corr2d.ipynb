# %% [markdown]
# ### Import libraries

# %%
# Import libraries
import fnmatch
import scipy.io as sio
import os
from keras.models import Sequential, Model, load_model
from keras import backend as BK
import numpy as np
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\sally\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Step.1: define variable and data path

# %%
speaker = 's25'
compareGf = 60

model ='s1_s10_s17_s27_s16_s11_s15_s25'

# Step.1: define variable and data path
print('***** Step.1: Define variable and data path *******')
oriSpecPath = 'D:/Mrs_backup/speech_test/AudSpecs/'+speaker+'/'

# get the model input path 
modelInputPath = 'D:/Mrs_backup/speech_test/cnn/input/'+speaker+'/'

autoModelPath = 'D:/Mrs_backup/speech_test/autoencoder/'+speaker+'_trainModel/'

lipModelPath = 'D:/Mrs_backup/speech_test/cnn/output/'+model+'/'

print('Original spectrogram path is: '+ str(oriSpecPath)+'\n') 
print('Model input path is: '+ str(modelInputPath)+'\n')
print('Autoencoder model path is: '+ str(autoModelPath)+'\n')
print('Main Model path is: '+ str(lipModelPath)+'\n')

evalPath = 'D:/Mrs_backup/speech_test/corr2d/cnn/'+model+'/'
if not os.path.exists(evalPath):
    os.mkdir(evalPath )
    
evalPath = evalPath + speaker+'/'
if not os.path.exists(evalPath):
    os.mkdir(evalPath )    
print('Result output path is: '+ str(evalPath)+'\n')
print('---------------  End of Step.1  --------------------- ')
# Out:
# ***** Step.1: Define variable and data path *******
# Original spectrogram path is: D:/Mrs_backup/speech_test/AudSpecs/s25/
#
# Model input path is: D:/Mrs_backup/speech_test/cnn/input/s25/
#
# Autoencoder model path is: D:/Mrs_backup/speech_test/autoencoder/s25_trainModel/
#
# Main Model path is: D:/Mrs_backup/speech_test/cnn/output/s1_s10_s17_s27_s16_s11_s15_s25/
#
# Result output path is: D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/
#
# ---------------  End of Step.1  ---------------------

# %% [markdown]
# ### Step.2: count train and test set

# %%
def countTrainAndTest(modelInputPath,numSlices):
    numTrain=len(fnmatch.filter(os.listdir(modelInputPath),'preprocessed_data_final_part*.mat'))
    mat=sio.loadmat(modelInputPath+'preprocessed_data_final_validation.mat')
    print(mat['video_input'].shape)
    numTest = int(mat['video_input'].shape[0]/numSlices)
    return numTrain,numTest


print('***** Step.2: Count train and test set *******')
numSlices=15
numTrain,numTest = countTrainAndTest(modelInputPath,numSlices)
print('Number of training set is: '+ str(numTrain))
print('Number of test set is: '+ str(numTest))
print('---------------  End of Step.2  --------------------- ')
# Out:
# ***** Step.2: Count train and test set *******
# (300, 3, 128, 128, 5)
# Number of training set is: 80
# Number of test set is: 20
# ---------------  End of Step.2  ---------------------

# %% [markdown]
# ### Step.3: load data and get input shape

# %%
def getOriAudioSize(oriSpecPath):
    filePath = oriSpecPath + os.listdir(oriSpecPath)[0]
    mat=sio.loadmat(filePath)
    audioSize = mat['y'].shape
    return audioSize

# Step.3: load data and get input shape
print('***** Step.3: Count train and test set *******')
audioSize = getOriAudioSize(oriSpecPath)
audioSpecLength = audioSize[0]
audioSpecFreq = audioSize[1]
print('Audio Spectrogram length is: '+ str(audioSpecLength))
print('Audio Spectrogram Freqence is: '+ str(audioSpecFreq))
print('---------------  End of Step.3  --------------------- ')
# Out:
# ***** Step.3: Count train and test set *******
# Audio Spectrogram length is: 376
# Audio Spectrogram Freqence is: 128
# ---------------  End of Step.3  ---------------------

# %% [markdown]
# ### Step.4: load autoencoder and main model

# %%
# Define cost function
def corr2_mse_loss(a,b):
    a = BK.tf.subtract(a, BK.tf.reduce_mean(a))
    b = BK.tf.subtract(b, BK.tf.reduce_mean(b))
    tmp1 = BK.tf.reduce_sum(BK.tf.multiply(a,a))
    tmp2 = BK.tf.reduce_sum(BK.tf.multiply(b,b))
    tmp3 = BK.tf.sqrt(BK.tf.multiply(tmp1,tmp2))
    tmp4 = BK.tf.reduce_sum(BK.tf.multiply(a,b))
    r = -BK.tf.divide(tmp4,tmp3)
    m=BK.tf.reduce_mean(BK.tf.square(BK.tf.subtract(a, b)))
    rm=BK.tf.add(r,m)
    return rm

def loadModel(autoModelPath,lipModelPath):
    # Loading AutoEncoder model
    autoModel=load_model(autoModelPath+'autoencoder.h5',custom_objects={'corr2_mse_loss': corr2_mse_loss})
    autoModel.load_weights(autoModelPath+'autoencoder_weights.h5')
    
    #  Loading LipReading model
    lipModel=load_model(lipModelPath+'model_LipReading.h5',custom_objects={'corr2_mse_loss': corr2_mse_loss})
    #Best weights
    lipModel.load_weights(lipModelPath+'Best_weights_LipReading.h5')
    return autoModel,lipModel


print('***** Step.5: Load autoencoder and main model *******')
autoModel,lipModel = loadModel(autoModelPath,lipModelPath)
print('Autoencoder and lipReading model has loaded.... ')
print('---------------  End of Step.5  --------------------- ')
# Out:
# ***** Step.5: Load autoencoder and main model *******
# Autoencoder and lipReading model has loaded....
# ---------------  End of Step.5  ---------------------

# %% [markdown]
# ### Step.5: load original spectrogram, generate autoencoder spectrogram and predicted spectrogram

# %%
def corr2(a,b):
    k = np.shape(a)
    H=k[0]
    W=k[1]
    c = np.zeros((H,W))
    d = np.zeros((H,W))
    e = np.zeros((H,W))

    #Calculating mean values
    AM=np.mean(a)
    BM=np.mean(b)  

    #Calculating terms of the formula
    for ii in range(H):
        for jj in range(W):
            c[ii,jj]=(a[ii,jj]-AM)*(b[ii,jj]-BM)
            d[ii,jj]=(a[ii,jj]-AM)**2
            e[ii,jj]=(b[ii,jj]-BM)**2

    #Formula itself
    r = np.sum(c)/float(np.sqrt(np.sum(d)*np.sum(e)))
    return r

#Define get_activations function
def get_activations(model, layer_in, layer_out, X_batch):
    get_activations = BK.function([model.layers[layer_in].input, BK.learning_phase()], [model.layers[layer_out].output])
    activations = get_activations([X_batch,0])
    return activations

def getPredictedAudio(modelOutput,bottleFeature,sliceLength):
    specOutput=np.reshape(modelOutput,(modelOutput.shape[0],bottleFeature,sliceLength))
    specOutput2=np.concatenate(specOutput,axis=1)
    decodeOutput =get_activations(autoModel, 13, 19, specOutput2.T)[0]
    finalPredictSpec = np.power(decodeOutput,3)
    return finalPredictSpec


def getAutoSpec(oriSpec):
    oriOutput = autoModel.predict(np.power(oriSpec,.3))
    autoSpec = np.power(oriOutput,3)
    return autoSpec

def getAutoSpec2(oriSpec):
    oriOutput = autoModel.predict(np.power(oriSpec,.3))
    autoSpec = np.power(oriOutput,3)
    return autoSpec

def predictSpec(inputFile):
    trainInput = sio.loadmat(inputFile)['video_input'][:,:,:,:,0:23]
    modelOutput = lipModel.predict(trainInput) 
    finalPredictSpec = getPredictedAudio(modelOutput,bottleFeature=32,sliceLength=26)
    return finalPredictSpec

def predictSpecTest(testInput):
    modelOutput = lipModel.predict(testInput) 
    finalPredictSpec = getPredictedAudio(modelOutput,bottleFeature=32,sliceLength=26)
    print(finalPredictSpec.shape)
    return finalPredictSpec

# %%
trainAutoCorr = np.empty((numTrain), np.dtype('float32'))
trainPreCorr = np.empty((numTrain), np.dtype('float32'))
testAutoCorr = np.empty((numTest), np.dtype('float32'))
testPreCorr = np.empty((numTest), np.dtype('float32'))

print('---------- Load train file -----------------')
trainFile = fnmatch.filter(os.listdir(modelInputPath),'preprocessed_data_final_part*.mat')
trainResult = evalPath+'train/'
if not os.path.exists(trainResult):
    os.mkdir(trainResult )
cor2DTrainPath = evalPath + 'cor2D_train.mat'

print('---------- Load test file -----------------')
testData = sio.loadmat(modelInputPath+'preprocessed_data_final_validation.mat')['video_input']  
testResult = evalPath+'test/'
if not os.path.exists(testResult):
    os.mkdir(testResult)  
cor2DTestPath = evalPath + 'cor2D_test.mat'
# Out:
# ---------- Load train file -----------------
# ---------- Load test file -----------------

# %%
print('***** Step.5: load original spectrogram and Generate autoencoder spectrogram *******')  
i=0  
testCount = 0
for count, filename in enumerate(sorted(os.listdir(oriSpecPath)),start=0): 

    # Get the train result
    if count in range(numTrain):
        audioFile  =oriSpecPath+ filename 
        print('Audio File is:' +audioFile)

        # Get original spectrogram
        oriSpec =sio.loadmat(audioFile)['y']
        print('Original spectrogram shape is:'+ str(oriSpec.shape))
        
        #Get autoencoder spectrogram
#         autoSpec = getAutoSpec(oriSpec)
#         autoCorr = corr2(oriSpec,autoSpec)
#         trainAutoCorr[count] = autoCorr
#         print('Autoencoder spectrogram shape is:'+ str(autoSpec.shape))
#         print('Reconstruted spectrogram from autoencoder with correlation '+str(autoCorr))  

        #Get the predicted spectrogram and save it into train set
        inputFile= modelInputPath+trainFile[count]
        finalPredictSpec = predictSpec(inputFile)
        sio.savemat(trainResult+filename, mdict={'audio_input':finalPredictSpec})
    
        preCorr = corr2(oriSpec,finalPredictSpec)
        trainPreCorr[count] = preCorr
        
        #print('Final predicted spectrogram shape is:'+ str(finalPredictSpec.shape))
        print('Reconstruted spectrogram from lipreading model with correlation '+str(preCorr)+'\n') 
        
    else:
        audioFile  =oriSpecPath+ filename 
        print('Audio File is:' +audioFile) 
        
        # Get original spectrogram
        oriSpec =sio.loadmat(audioFile)['y']
        
#         # Get autoencoder spectrogram
#         autoSpec = getAutoSpec(oriSpec)
#         autoCorr = corr2(oriSpec,autoSpec)
#         testAutoCorr[testCount] = autoCorr
        
        # Get the predicted spectrogram and save it into test set
        testInput = testData[i:(i+numSlices),:,:,:,0:23]
        #print(testInput.shape)
        finalPredictSpec = predictSpecTest(testInput)
        sio.savemat(testResult+filename, mdict={'audio_input':finalPredictSpec})
        
        preCorr = corr2(oriSpec,finalPredictSpec)
        testPreCorr[testCount] = preCorr
        
        #print('Final predicted spectrogram shape is:'+ str(finalPredictSpec.shape))
        print('Reconstruted spectrogram from lipreading model with correlation '+str(preCorr)+'\n')
        i=i+numSlices
        testCount=testCount+1
        
sio.savemat(cor2DTrainPath, mdict={'corr2':trainPreCorr})
sio.savemat(cor2DTestPath, mdict={'corr2':testPreCorr})
print('Correclation value from training set has been saved in path: '+ str(cor2DTrainPath))
print('Correclation value from test set has been saved in path: '+ str(cor2DTestPath))
print('Average correlation value from training set is: '+str(np.mean(trainPreCorr)))
print('Average correlation value from test set is: '+str(np.mean(testPreCorr))+'\n')
# Out:
# ***** Step.5: load original spectrogram and Generate autoencoder spectrogram *******
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/000.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.22999645892603415
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/001.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.26297880833976767
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/002.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2835198897806128
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/003.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2610223802580896
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/004.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2953422186619177
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/005.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2509586287620564
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/006.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2965673039845396
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/007.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.16164898603525465
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/008.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1269851608713169
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/009.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1371797039469601
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/010.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.23537937457422795
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/011.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2434379588449376
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/012.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.32637015642672534
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/013.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3528843651196958
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/014.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.22430665839780226
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/015.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2530021112212959
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/016.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.15624188750335805
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/017.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.19925787226680539
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/018.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.35149600049861074
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/019.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.18922319939645976
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/020.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.11486395720418024
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/021.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2278165644162257
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/022.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.28831584406670047
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/023.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.32604053044507547
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/024.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.19840381461163253
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/025.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2894417152086474
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/026.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.15309445277729775
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/027.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.23610020889223735
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/028.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2736900832217364
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/029.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.21174389235980623
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/030.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1575998321852113
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/031.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.18425602376517272
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/032.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.24069847375128614
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/033.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.25862009581425294
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/034.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.19005376650404493
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/035.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.23185576892258647
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/036.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.17300279750561998
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/037.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3486327580478534
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/038.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3294389893838453
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/039.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.36304550231651384
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/040.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2375927083093213
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/041.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.15425219262874046
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/042.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3069724928769104
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/043.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.21289852638955742
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/044.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.17732477778334255
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/045.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.20119887613490986
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/046.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3523857147171353
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/047.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.23705191020136943
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/048.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.18811673544969656
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/049.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1634962669394437
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/050.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.33585535820063855
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/051.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1872190214442104
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/052.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.13287267156809382
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/053.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.06632506773679009
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/054.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.20481504968561026
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/055.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2316778466076606
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/056.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2115321883557937
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/057.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.16226759556999729
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/058.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.09644062723641414
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/059.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.16594810197881613
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/060.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.19639821141903152
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/061.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2145149691107552
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/062.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2757530993333762
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/063.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2759029193883446
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/064.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2814500058755989
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/065.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.24825743462104274
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/066.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1285670528566315
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/067.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.25171232855337916
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/068.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2753108590928021
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/069.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.27805507628769094
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/070.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.22288839812401479
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/071.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.25331313403854044
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/072.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.1872043022949468
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/073.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.21447246652402502
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/074.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.29345619021398256
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/075.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3025255258915223
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/076.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.23585369194581912
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/077.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.340444412814368
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/078.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2633056974190504
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/079.mat
# Original spectrogram shape is:(376, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3012057033708812
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/080.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.18949944900948823
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/081.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2511735977901563
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/082.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.29643501291630064
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/083.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2876067645325945
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/084.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2299818543332435
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/085.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.3621221311181973
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/086.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.27616456949978585
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/087.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2311253483634336
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/088.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.2509991304906211
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/089.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.17272971100188783
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/090.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.35666725048071535
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/091.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.31288557116429633
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/092.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.44828934886744753
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/093.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.32211661619685067
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/094.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.41157161172652945
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/095.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.33353453981463294
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/096.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.19751695671505232
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/097.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.16880942481960032
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/098.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.21386205579415518
#
# Audio File is:D:/Mrs_backup/speech_test/AudSpecs/s25/099.mat
# (390, 128)
# Reconstruted spectrogram from lipreading model with correlation 0.17544475031195056
#
# Correclation value from training set has been saved in path: D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/cor2D_train.mat
# Correclation value from test set has been saved in path: D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/cor2D_test.mat
# Average correlation value from training set is: 0.23376687
# Average correlation value from test set is: 0.27442676

# %% [markdown]
# ### Step 6:  Result analysis

# %%
# def removeOutliers(corrData):
#     # calculate summary statistics
#     data_mean, data_std = mean(corrData), std(corrData)
#     #print('Original data mean is '+ str(data_mean))

#     # identify outliers
#     cut_off = data_std * 2
#     lower, upper = data_mean - cut_off, data_mean + cut_off
    
#     # identify outliers
#     outliers = [x for x in corrData if x < lower or x > upper]
#     #print('Identified outliers: %d' % len(outliers)+ ', which is '+str(outliers))

#     # remove outliers
#     outliers_removed = [x for x in corrData if x >= lower and x <= upper]
#     #print('Non-outlier observations: %d' % len(outliers_removed))
#     print(outliers_removed)
    
#     avgCorr = np.mean(outliers_removed)
    
#     return avgCorr

# %% [markdown]
# ### Training set result analysis

# %%
print(trainPreCorr)
stdAvgTrain = np.mean(trainPreCorr)
print('Average correlation value from training set is: '+str(stdAvgTrain))
# stdAvgTrain = removeOutliers(trainPreCorr)
# stdAvgTrain = np.mean(trainPreCorr)
# print('Average correlation value from training set is: '+str(stdAvgTrain))
# Out:
# [0.22999646 0.26297882 0.2835199  0.2610224  0.2953422  0.25095862
#  0.2965673  0.16164899 0.12698516 0.1371797  0.23537937 0.24343796
#  0.32637015 0.35288435 0.22430666 0.2530021  0.1562419  0.19925787
#  0.351496   0.1892232  0.11486395 0.22781657 0.28831583 0.32604054
#  0.19840382 0.2894417  0.15309446 0.23610021 0.27369007 0.21174389
#  0.15759984 0.18425602 0.24069847 0.25862008 0.19005376 0.23185576
#  0.1730028  0.34863275 0.32943898 0.3630455  0.23759271 0.15425219
#  0.3069725  0.21289852 0.17732477 0.20119888 0.35238573 0.2370519
#  0.18811673 0.16349627 0.33585536 0.18721902 0.13287267 0.06632507
#  0.20481504 0.23167785 0.21153219 0.1622676  0.09644063 0.16594811
#  0.19639821 0.21451497 0.2757531  0.27590293 0.28145    0.24825743
#  0.12856705 0.25171232 0.27531087 0.27805507 0.2228884  0.25331312
#  0.1872043  0.21447247 0.2934562  0.30252552 0.23585369 0.34044442
#  0.2633057  0.3012057 ]
# Average correlation value from training set is: 0.23376687

# %%
(maxCorrtTrain,maxIndexTrain) = max((v,i) for i,v in enumerate(trainPreCorr))
print ('Maxmum correlation value from training set is: '+str(maxCorrtTrain)+' on video: '+str(maxIndexTrain))
# Out:
# Maxmum correlation value from training set is: 0.3630455 on video: 39

# %%
maxCorr = evalPath+'maxCorr/'
if not os.path.exists(maxCorr):
    os.mkdir(maxCorr )

# %%
maxCorrTrain = maxCorr+'train/'
if not os.path.exists(maxCorrTrain):
    os.mkdir(maxCorrTrain )

# %%
# Plot maxmum spectrogram from train set and save the output
# Load maxOri spectrogram
maxNum="{number:03}".format(number=(maxIndexTrain))

maxOriPath = oriSpecPath+ maxNum+'.mat'
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTrain+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = trainResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTrain+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/train/039.mat
# (390, 128)

# %%
# Plot maxmum spectrogram from train set and save the output
# Load maxOri spectrogram
#maxNum="{number:03}".format(number=(maxIndexTrain))
maxNum="{number:03}".format(number=(compareGf))
# maxNum="{number:03}".format(number=(65))# 

maxOriPath = oriSpecPath+ maxNum+'.mat'
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTrain+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = trainResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTrain+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTrain+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/train/060.mat
# (390, 128)

# %% [markdown]
# ### Test set result analysis

# %%
print(testPreCorr)
#print('Average correlation value from training set is: '+str(np.mean(testPreCorr)))
stdAvgTest=np.mean(testPreCorr)
# stdAvgTest = removeOutliers(testPreCorr)
print('Average correlation value from training set is: '+str(stdAvgTest))
# Out:
# [0.18949945 0.2511736  0.296435   0.28760678 0.22998185 0.36212212
#  0.27616456 0.23112535 0.25099912 0.17272972 0.35666725 0.31288558
#  0.44828933 0.3221166  0.41157162 0.33353454 0.19751696 0.16880943
#  0.21386206 0.17544475]
# Average correlation value from training set is: 0.27442676

# %%
(maxCorrtTest,maxIndexTest) = max((v,i) for i,v in enumerate(testPreCorr))
print ('Maxmum correlation value from test set is: '+str(maxCorrtTest)+' on video: '+str(maxIndexTest))
# Out:
# Maxmum correlation value from test set is: 0.44828933 on video: 12

# %%
maxCorrTest = maxCorr+'test/'
if not os.path.exists(maxCorrTest):
    os.mkdir(maxCorrTest )

# %%
# Load maxOri spectrogram
maxNum="{number:03}".format(number=(maxIndexTest+numTrain))
maxOriPath = oriSpecPath+ maxNum+'.mat'
print(maxOriPath)
MaxOriSpec =sio.loadmat(maxOriPath)['y']
print(MaxOriSpec.shape)
sio.savemat(maxCorrTest+maxNum+'_ori.mat', mdict={'audio_input':MaxOriSpec})

figure1 = plt.figure(1,figsize=(15, 5))
plt.title('Original Sample')
plt.imshow(MaxOriSpec.T, origin="lower", aspect="auto", interpolation="none")
figure1.savefig(maxCorrTest+maxNum+'_Original spectrogram.png', dpi=figure1.dpi)

# Load maxPre spectrogram
maxPrePath = testResult+ maxNum+'.mat'
print(maxPrePath)
MaxPreSpec =sio.loadmat(maxPrePath)['audio_input']
print(MaxPreSpec.shape)
sio.savemat(maxCorrTest+maxNum+'_pre.mat', mdict={'audio_input':MaxPreSpec})

# Plot Reconstruted spectrogram after reserving the compression process
figure2 = plt.figure(2,figsize=(15, 5))
plt.imshow(MaxPreSpec[0:373,].T, origin="lower", aspect="auto", interpolation="none")
plt.title('Reconstructed Spectrogram \n Corr2(Original,Reconstructed)= %.3f'%corr2(MaxOriSpec[0:373,],MaxPreSpec[0:373,]))
figure2.savefig(maxCorrTest+maxNum+'_Reconstruted spectrogram.png', dpi=figure1.dpi)
# Out:
# D:/Mrs_backup/speech_test/AudSpecs/s25/092.mat
# (376, 128)
# D:/Mrs_backup/speech_test/corr2d/cnn/s1_s10_s17_s27_s16_s11_s15_s25/s25/test/092.mat
# (390, 128)

# %% [markdown]
# ### Save avg and max value from training and test set

# %%
sio.savemat(evalPath+'/corr2D.mat', mdict={'train_avg':stdAvgTrain,
                                           'train_max':maxCorrtTrain,
                                           'train_index':maxIndexTrain,
                                           'test_avg':stdAvgTest, 
                                           'test_max':maxCorrtTest,
                                           'test_index':maxIndexTest})

# %%
print('Average correlation value from training set is: '+str(stdAvgTrain))
print ('Maxmum correlation value from training set is: '+str(maxCorrtTrain)+' on video: '+str(maxIndexTrain))
# Out:
# Average correlation value from training set is: 0.23376687
# Maxmum correlation value from training set is: 0.3630455 on video: 39

# %%
print('Average correlation value from training set is: '+str(stdAvgTest))
print ('Maxmum correlation value from test set is: '+str(maxCorrtTest)+' on video: '+str(maxIndexTest))
# Out:
# Average correlation value from training set is: 0.27442676
# Maxmum correlation value from test set is: 0.44828933 on video: 12
